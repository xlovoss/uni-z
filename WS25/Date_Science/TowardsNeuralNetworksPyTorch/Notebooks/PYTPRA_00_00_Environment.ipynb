# %%
#Lade testweise alle Pakete und gib Versionen aus

# %%
import captum
import matplotlib 
import scipy 
import sklearn 
import math
import numpy as np
import os
import pandas as pd #for df
import seaborn as sns #for charts
import statsmodels
import time
import torch #no "as t" for pedagogic reasons to be aware for torch

# %%
#print(torch.cuda.device_count())
if(torch.cuda.device_count()):
    print("GPU available")
#alphabetical order
print('captum version: %r' % captum.__version__)
print('matplotlib version: %r' % matplotlib.__version__)
print('scipy version: %r' % scipy.__version__)
print('sklearn version: %r' % sklearn.__version__)
print('numpy version: %r' % np.__version__)
print('pandas version: %r' % pd.__version__)
print('seaborn version: %r' % sns.__version__)
print('statsmodels version: %r' % statsmodels.__version__)
print('torch version: %r' % torch.__version__)
# Out:
# captum version: '0.6.0'
# matplotlib version: '3.7.0'
# scipy version: '1.10.0'
# sklearn version: '1.2.1'
# numpy version: '1.23.5'
# pandas version: '1.5.3'
# seaborn version: '0.12.2'
# statsmodels version: '0.13.5'
# torch version: '1.12.1'

# %%
! python --version
# Out:
# Python 3.10.9
